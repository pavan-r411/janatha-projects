# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
df.groupby(['gender','is_promoted']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-204-4b690a94af5e> in <module>
# ----> 1 df.groupby(['gender','is_promoted']).count()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
# ...

# %%
df.groupby('gender').count()
# Out:
#         employee_id  department  region  education  recruitment_channel  \
# gender
# f              6894        6894    6894       6715                 6894
# m             16596       16596   16596      15741                16596
#
#         no_of_trainings    age  previous_year_rating  length_of_service  \
# gender
# f                  6894   6894                  6392               6894
# m                 16596  16596                 15286              16596
#
#         KPIs_met >80%  awards_won?  avg_training_score
# gender
# f                6894         6894                6894
# m               16596        16596               16596

# %%
df = df.drop(['education'],axis=1)

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
df.corr()
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.005433  0.000920
# no_of_trainings         -0.005433         1.000000 -0.085509
# age                      0.000920        -0.085509  1.000000
# previous_year_rating    -0.005963        -0.047348  0.016421
# length_of_service        0.011781        -0.061095  0.644515
# KPIs_met >80%            0.006285        -0.040020 -0.027661
# awards_won?              0.000118         0.001892 -0.005457
# avg_training_score      -0.011735         0.048121 -0.035823
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                      -0.005963           0.011781       0.006285
# no_of_trainings                  -0.047348          -0.061095      -0.040020
# age                               0.016421           0.644515      -0.027661
# previous_year_rating              1.000000           0.003047       0.349350
# ...

# %%
df[df['previous_year_rating'].isnull()]
# Out:
#        employee_id         department     region gender recruitment_channel  \
# 0             8724         Technology  region_26      m            sourcing
# 21            5677         Technology  region_17      m            sourcing
# 32           67672         Technology  region_17      m               other
# 39           55325          Analytics  region_22      m               other
# 47           44159          Analytics  region_22      m               other
# ...            ...                ...        ...    ...                 ...
# 23406        53291         Operations   region_4      m            sourcing
# 23436        10138         Technology   region_2      f            referred
# 23445        65765          Analytics  region_31      m            sourcing
# 23479        39410  Sales & Marketing   region_2      m               other
# 23488         1186        Procurement  region_31      m            sourcing
#
# ...

# %%
df['previous_year_rating'].unique()
# Out:
# array([nan,  3.,  1.,  2.,  4.,  5.])

# %%
df.corr()
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.005433  0.000920
# no_of_trainings         -0.005433         1.000000 -0.085509
# age                      0.000920        -0.085509  1.000000
# previous_year_rating    -0.005963        -0.047348  0.016421
# length_of_service        0.011781        -0.061095  0.644515
# KPIs_met >80%            0.006285        -0.040020 -0.027661
# awards_won?              0.000118         0.001892 -0.005457
# avg_training_score      -0.011735         0.048121 -0.035823
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                      -0.005963           0.011781       0.006285
# no_of_trainings                  -0.047348          -0.061095      -0.040020
# age                               0.016421           0.644515      -0.027661
# previous_year_rating              1.000000           0.003047       0.349350
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'gender', 'recruitment_channel',
#        'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score'],
#       dtype='object')

# %%
xtemp = df[['age','length_of_service','KPIs_met >80%','previous_year_rating']]

# %%
xtemp.head()
# Out:
#    age  length_of_service  KPIs_met >80%  previous_year_rating
# 0   24                  1              1                   NaN
# 1   31                  5              0                   3.0
# 2   31                  4              0                   1.0
# 3   31                  9              0                   2.0
# 4   30                  7              0                   4.0

# %%
xtemp = xtemp.dropna()

# %%
xtemp.isnull().sum()
# Out:
# age                     0
# length_of_service       0
# KPIs_met >80%           0
# previous_year_rating    0
# dtype: int64

# %%
x_l = xtemp.iloc[:,0:3].values
y_l = xtemp.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_l, y_l)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
xpred = df[['age','length_of_service','KPIs_met >80%','previous_year_rating']]

# %%
xpred = xpred[xpred['previous_year_rating'].isnull()]

# %%
xpred.head()
# Out:
#     age  length_of_service  KPIs_met >80%  previous_year_rating
# 0    24                  1              1                   NaN
# 21   25                  1              0                   NaN
# 32   29                  1              1                   NaN
# 39   25                  1              0                   NaN
# 47   31                  1              1                   NaN

# %%
x_p = xpred.iloc[:,0:3].values
x_p
# Out:
# array([[24,  1,  1],
#        [25,  1,  0],
#        [29,  1,  1],
#        ...,
#        [28,  1,  0],
#        [20,  1,  0],
#        [27,  1,  0]], dtype=int64)

# %%
res = regressor.predict(x_p)
res
# Out:
# array([3.86869742, 2.94369387, 3.87865092, ..., 2.94966597, 2.93374037,
#        2.94767527])

# %%
import numpy as np
np.floor(res)
# Out:
# array([3., 2., 3., ..., 2., 2., 2.])

# %%
nullindexlist=df[df['previous_year_rating'].isnull()].index.tolist()

# %%
nullindexlist
# Out:
# [0,
#  21,
#  32,
#  39,
#  47,
#  53,
#  54,
#  63,
#  102,
#  103,
#  127,
#  154,
#  161,
#  162,
#  164,
#  172,
#  174,
#  187,
#  191,
#  204,
#  206,
#  216,
#  222,
#  223,
#  233,
#  244,
#  249,
#  271,
#  286,
#  296,
#  327,
#  341,
#  343,
#  368,
#  382,
#  409,
#  415,
#  416,
#  426,
#  428,
#  436,
#  443,
#  449,
#  467,
#  469,
#  471,
#  505,
#  535,
#  540,
#  549,
#  572,
#  579,
#  616,
#  625,
#  636,
#  647,
#  651,
#  660,
#  664,
#  671,
#  673,
#  707,
#  713,
#  720,
#  731,
#  733,
#  777,
#  783,
#  784,
#  789,
#  806,
#  809,
#  821,
#  854,
#  860,
#  886,
#  915,
#  925,
#  934,
#  951,
#  961,
#  966,
#  982,
#  1000,
#  1021,
#  1024,
#  1025,
#  1043,
#  1046,
#  1064,
#  1071,
#  1080,
#  1085,
#  1096,
#  1172,
#  1185,
#  1187,
#  1220,
#  1243,
#  1251,
#  1259,
#  1267,
#  1275,
#  1293,
#  1294,
#  1305,
#  1327,
#  1328,
#  1338,
#  1340,
#  1361,
#  1376,
#  1386,
#  1401,
#  1406,
#  1410,
#  1412,
#  1422,
#  1430,
#  1457,
#  1469,
# ...

# %%
count=0
temp = df['previous_year_rating']
z = int(temp.shape[0])
z
import numpy as np
for i in range(0,z-1):
    if np.isnan(temp[i]):
        temp[i] = np.floor(res[count])
        count =count+1
# Out:
# C:\Users\PAVAN\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
temp.head(11)
# Out:
# 0     3.0
# 1     3.0
# 2     1.0
# 3     2.0
# 4     4.0
# 5     3.0
# 6     5.0
# 7     3.0
# 8     4.0
# 9     5.0
# 10    5.0
# Name: previous_year_rating, dtype: float64

# %%
temp.isnull().sum()
# Out:
# 0

# %%
df = pd.concat([df.drop(['previous_year_rating'],axis=1),temp], axis=1)

# %%
df.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# previous_year_rating    0
# dtype: int64

# %%
df.head()
# Out:
#    employee_id         department     region gender recruitment_channel  \
# 0         8724         Technology  region_26      m            sourcing
# 1        74430                 HR   region_4      f               other
# 2        72255  Sales & Marketing  region_13      m               other
# 3        38562        Procurement   region_2      f               other
# 4        64486            Finance  region_29      m            sourcing
#
#    no_of_trainings  age  length_of_service  KPIs_met >80%  awards_won?  \
# 0                1   24                  1              1            0
# 1                1   31                  5              0            0
# 2                1   31                  4              0            0
# 3                3   31                  9              0            0
# 4                1   30                  7              0            0
#
#    avg_training_score  previous_year_rating
# 0                  77                   3.0
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# previous_year_rating    0
# dtype: int64

# %%
df.head()
# Out:
#    employee_id         department     region gender recruitment_channel  \
# 0         8724         Technology  region_26      m            sourcing
# 1        74430                 HR   region_4      f               other
# 2        72255  Sales & Marketing  region_13      m               other
# 3        38562        Procurement   region_2      f               other
# 4        64486            Finance  region_29      m            sourcing
#
#    no_of_trainings  age  length_of_service  KPIs_met >80%  awards_won?  \
# 0                1   24                  1              1            0
# 1                1   31                  5              0            0
# 2                1   31                  4              0            0
# 3                3   31                  9              0            0
# 4                1   30                  7              0            0
#
#    avg_training_score  previous_year_rating
# 0                  77                   3.0
# ...

# %%
df.count()
# Out:
# employee_id             23490
# department              23490
# region                  23490
# gender                  23490
# recruitment_channel     23490
# no_of_trainings         23490
# age                     23490
# length_of_service       23490
# KPIs_met >80%           23490
# awards_won?             23490
# avg_training_score      23490
# previous_year_rating    23490
# dtype: int64

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'gender', 'recruitment_channel',
#        'no_of_trainings', 'age', 'length_of_service', 'KPIs_met >80%',
#        'awards_won?', 'avg_training_score', 'previous_year_rating'],
#       dtype='object')

# %%
dataframe = df[['department', 'region', 'recruitment_channel',
       'no_of_trainings', 'age', 'length_of_service', 'KPIs_met >80%',
       'awards_won?', 'avg_training_score','is_promoted']]

# %%
dataframe.head()
# Out:
#           department     region recruitment_channel  no_of_trainings  age  \
# 0         Technology  region_26            sourcing                1   24
# 1                 HR   region_4               other                1   31
# 2  Sales & Marketing  region_13               other                1   31
# 3        Procurement   region_2               other                3   31
# 4            Finance  region_29            sourcing                1   30
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# 1                  5              0            0                  51
# 2                  4              0            0                  47
# 3                  9              0            0                  65
# 4                  7              0            0                  61

# %%
dataframe['department'].unique()
# Out:
# array(['Technology', 'HR', 'Sales & Marketing', 'Procurement', 'Finance',
#        'Analytics', 'Operations', 'Legal', 'R&D'], dtype=object)

# %%
dataframe.groupby(['department','is_promoted']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-242-3280f68a4884> in <module>
# ----> 1 dataframe.groupby(['department','is_promoted']).count()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
# ...

# %%
appendvr2testdf = pd.get_dummies(dataframe[['department']],drop_first=True)
dataframe = pd.concat([dataframe.drop(['department'],axis=1),appendvr2testdf], axis=1)

# %%
appendvr2testdf = pd.get_dummies(dataframe[['recruitment_channel']],drop_first=True)
dataframe = pd.concat([dataframe.drop(['recruitment_channel'],axis=1),appendvr2testdf], axis=1)

# %%
dataframe.head()
# Out:
#       region  no_of_trainings  age  length_of_service  KPIs_met >80%  \
# 0  region_26                1   24                  1              1
# 1   region_4                1   31                  5              0
# 2  region_13                1   31                  4              0
# 3   region_2                3   31                  9              0
# 4  region_29                1   30                  7              0
#
#    awards_won?  avg_training_score  department_Finance  department_HR  \
# 0            0                  77                   0              0
# 1            0                  51                   0              1
# 2            0                  47                   0              0
# 3            0                  65                   0              0
# 4            0                  61                   1              0
#
#    department_Legal  department_Operations  department_Procurement  \
# ...

# %%
dataframe['region'].unique()
# Out:
# array(['region_26', 'region_4', 'region_13', 'region_2', 'region_29',
#        'region_7', 'region_22', 'region_16', 'region_17', 'region_24',
#        'region_11', 'region_27', 'region_9', 'region_20', 'region_34',
#        'region_23', 'region_8', 'region_14', 'region_31', 'region_19',
#        'region_5', 'region_28', 'region_15', 'region_3', 'region_25',
#        'region_12', 'region_21', 'region_30', 'region_10', 'region_33',
#        'region_32', 'region_6', 'region_1', 'region_18'], dtype=object)

# %%
dataframe.columns
# Out:
# Index(['region', 'no_of_trainings', 'age', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score',
#        'department_Finance', 'department_HR', 'department_Legal',
#        'department_Operations', 'department_Procurement', 'department_R&D',
#        'department_Sales & Marketing', 'department_Technology',
#        'recruitment_channel_referred', 'recruitment_channel_sourcing'],
#       dtype='object')

# %%
dataframe = dataframe[['no_of_trainings', 'age', 'length_of_service',
       'KPIs_met >80%', 'awards_won?', 'avg_training_score',
       'department_Finance', 'department_HR', 'department_Legal',
       'department_Operations', 'department_Procurement', 'department_R&D',
       'department_Sales & Marketing', 'department_Technology',
       'recruitment_channel_referred', 'recruitment_channel_sourcing','is_promoted']]

# %%
dataframe.head()
# Out:
#    no_of_trainings  age  length_of_service  KPIs_met >80%  awards_won?  \
# 0                1   24                  1              1            0
# 1                1   31                  5              0            0
# 2                1   31                  4              0            0
# 3                3   31                  9              0            0
# 4                1   30                  7              0            0
#
#    avg_training_score  department_Finance  department_HR  department_Legal  \
# 0                  77                   0              0                 0
# 1                  51                   0              1                 0
# 2                  47                   0              0                 0
# 3                  65                   0              0                 0
# 4                  61                   1              0                 0
#
#    department_Operations  department_Procurement  department_R&D  \
# ...

# %%
X= dataframe.iloc[:, :]
y = dataframe.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size = 0.25,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-251-57498ed75742> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size = 0.25,random_state=0)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2094         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2095
# -> 2096     arrays = indexable(*arrays)
#    2097
#    2098     n_samples = _num_samples(arrays[0])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)

# Prediction the test set result
y_pred = classifier.predict(X_train)
# Out:
# C:\Users\PAVAN\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train, y_pred)

# %%
cm
# Out:
# array([[37497,    95],
#        [ 2857,   657]], dtype=int64)

# %%
ans = classifier.predict(X)

# %%
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_test,ans)

# %%
cm1
# Out:
# array([[12520,    28],
#        [  935,   219]], dtype=int64)

# %%
(12520+219)/(12520+28+935+219)
# Out:
# 0.929718289300832

# %%
ans
# Out:
# array([0., 0., 0., ..., 0., 0., 1.])

# %%
np.save(ans.npy)
